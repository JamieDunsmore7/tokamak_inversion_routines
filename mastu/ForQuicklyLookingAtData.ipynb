# %%
from mastu import HSV
import matplotlib.pyplot as plt
# %matplotlib widget

import numpy as np
import pyuda
client = pyuda.Client()

# %%
shotn = 50533

# %%
import BESplotting as bp
bp.subplotsBES(shotn)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ip = client.get('ip', shotn)

plt.figure()
ip.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import BESplotting as bp

# %%
2**13
# Out:
# 8192

# %%
import BESplotting as bp

for i in range(0, 8):
    bp.specplot(
        50936, 
        tplot=[0.6,1.1], 
        nperseg=2**15, 
        fplot=[80.,150.], 
        indI=4, indJ=i, 
        mx=-4., mn=-8., NL=4,
    )
    
for i in range(0, 8):
    bp.specplot(
        50936, 
        tplot=[-1.,-1.], 
        nperseg=2**15, 
        fplot=[0.,200.2], 
        indI=4, indJ=i, 
        mx=-4., mn=-8., NL=4,
    )
# Out:
#   File "/tmp/ipykernel_3230/3754706588.py", line 1
#     import BESplotting as bpfor i in range(0, 8):
#                                 ^
# SyntaxError: invalid syntax

# %%
for i in range(0, 8):
    bp.specplot(
    50936, 
    tplot=[-1.,-1.], 
    nperseg=2**15, 
    fplot=[0.,200.2], 
    indI=4, indJ=i, 
    mx=-4., mn=-8., NL=4,
)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import BES

# %%
sig, t, R, z = BES.getSingle(50936, I=4, J=7)

# %%
tt, ff, ss = mf.makeCrossSpectrogram(sig, t, sig, t, nperseg=2**15)

# %%
import my_funcs as mf
# Out:
# kk_cz couldnt be imported (SyntaxError)
# dd couldnt be imported

# %%
np.diff(ff)
# Out:
# array([122.07031249, 122.07031249, 122.07031249, ..., 122.07031249,
#        122.07031249, 122.07031249])

# %%
np.diff(tt)
# Out:
# array([0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096, 0.004096, 0.004096, 0.004096, 0.004096,
#        0.004096, 0.004096])

# %%
2**
