# %%
import numpy as np
import matplotlib.pyplot as plt
import pyuda
client = pyuda.Client()
import BESplotting as bp

# %matplotlib widget
# Out:
# -------------------Loading module Divertor-------------------
# -------------------Loading module Utilities-------------------

# %%
shotn = 51195
bp.subplotsBES(shotn)
# bp.minisubplots(shotn)
bp.plotSXR(shotn, )
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
shotn = 51196
bp.subplotsBES(shotn)
# bp.minisubplots(shotn)
bp.plotSXR(shotn, )
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
shotn = 51197
bp.subplotsBES(shotn)
# bp.minisubplots(shotn)
bp.plotSXR(shotn, )
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
shotn = 51198
bp.subplotsBES(shotn)
# bp.minisubplots(shotn)
bp.plotSXR(shotn, )
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ne0 = client.get('/AYC/ANE_NELINT', 51195)
ne = client.get('/AYC/ANE_NELINT', 51196)
ne1 = client.get('/AYC/ANE_NELINT', 51197)
ne2 = client.get('/AYC/ANE_NELINT', 51198)
plt.figure()
plt.plot(ne0.time.data, ne0.data, label=51195)
plt.plot(ne.time.data, ne.data, label=51196)
plt.plot(ne1.time.data, ne1.data, label=51197)
plt.plot(ne1.time.data, ne1.data, label=51198)
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
bp.subplotsBESMulti([51195,51196,51197,51198])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
