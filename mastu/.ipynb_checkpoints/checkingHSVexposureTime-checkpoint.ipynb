# %%
import functions as fn
import numpy as np
from mastu import HSV
import matplotlib.pyplot as plt
import my_funcs as mf
from pyEquilibrium.equilibrium import equilibrium as equil
import pyuda
client = pyuda.Client()
from scipy.optimize import curve_fit

# %matplotlib widget
# Out:
# -------------------Loading module Divertor-------------------
# -------------------Loading module Utilities-------------------
# kk_cz couldnt be imported (SyntaxError)
# dd couldnt be imported

# %%
dtime = 0.05

# %%
shotn0 = 51148
twant0 = 0.473296

trange = [twant0-dtime, twant0+dtime]
data0, time0 = HSV.get(shotn0, trange=trange)
tind0 = fn.findNearest(time0, twant0)

# %%
I0 = 243
J0 = 0
J00 = 250

fig, ax= plt.subplots(1, 1, figsize=(3.5,3), dpi=150)
im=ax.imshow(data0[:,:,tind0], vmin=0, vmax=100.,)
fig.colorbar(im, ax=ax)
ax.plot([J0,J00], [I0,I0], '-', c='C3', lw=0.8)
ax.tick_params(
    axis="both", which='both', labelsize=9, direction='in', 
    left=True, bottom=True, right=True, top=True
)
ax.minorticks_on()
ax.set_title(shotn0, fontsize=9)
plt.tight_layout()


fig, ax= plt.subplots(1, 1, figsize=(3.5,3), dpi=150)
for i in range(I0-5,I0+5):
    ax.plot(data0[i,J0:J00,tind0], label=i)
ax.tick_params(
    axis="both", which='both', labelsize=9, direction='in', 
    left=True, bottom=True, right=True, top=True
)
ax.minorticks_on()
ax.set_title(shotn0, fontsize=9)
plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
shotn1 = 51110
twant1 = 0.400013

trange = [twant1-dtime, twant1+dtime]
data1, time1 = HSV.get(shotn1, trange=trange)
tind1 = fn.findNearest(time1, twant1)

# %%
I1 = 243
J1 = 0
J11 = 250

fig, ax= plt.subplots(1, 1, figsize=(3.5,3), dpi=150)
im=ax.imshow(data1[:,:,tind1], vmin=0, vmax=100.,)
fig.colorbar(im, ax=ax)
ax.plot([J1,J11], [I1,I1], '-', c='C3', lw=0.8)
ax.tick_params(
    axis="both", which='both', labelsize=9, direction='in', 
    left=True, bottom=True, right=True, top=True
)
ax.minorticks_on()
ax.set_title(shotn1, fontsize=9)
plt.tight_layout()


fig, ax= plt.subplots(1, 1, figsize=(3.5,3), dpi=150)
for i in range(I1-5,I1+5):
    ax.plot(data1[i,J1:J11,tind1], label=i)
ax.tick_params(
    axis="both", which='both', labelsize=9, direction='in', 
    left=True, bottom=True, right=True, top=True
)
ax.minorticks_on()
ax.set_title(shotn1, fontsize=9)
plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
shotn2 = 51150
twant2 = 0.402341

trange = [twant2-dtime, twant2+dtime]
data2, time2 = HSV.get(shotn2, trange=trange)
tind2 = fn.findNearest(time2, twant2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_30605/187288591.py in <cell line: 2>()
#       1 shotn2 = 51150
# ----> 2 data2, time2 = HSV.get(shotn2)
#
# ~/tokamak_inversion_routines/mastu/HSV.py in get(shotn, trange, tind)
#      14         return getSingle(shotn, tind)
#      15
# ---> 16     data = client.get_images('rba', shotn)
#      17     # windowJ = slice(data.top, data.bottom + 1)
#      18     # windowI = slice(data.left, data.right + 1)
#
# /usr/local/depot/uda-mast-1.3.9/python/mast/mast_client.py in get_images(self, signal, source, first_frame, last_frame, stride, frame_number, header_only, rcc_calib_path)
#     110         comm += ')'
#     111
# --> 112         result = cpyuda.get_data(comm, "")
#     113         if result.error_code() != 0:
#     114             if result.error_message():
#
# KeyboardInterrupt:

# %%
I2 = 243
J2 = 0
J22 = 250

fig, ax= plt.subplots(1, 1, figsize=(3.5,3), dpi=150)
im=ax.imshow(data2[:,:,tind2], vmin=0, vmax=100.,)
fig.colorbar(im, ax=ax)
ax.plot([J2,J22], [I2,I2], '-', c='C3', lw=0.8)
ax.tick_params(
    axis="both", which='both', labelsize=9, direction='in', 
    left=True, bottom=True, right=True, top=True
)
ax.minorticks_on()
ax.set_title(shotn2, fontsize=9)
plt.tight_layout()


fig, ax= plt.subplots(1, 1, figsize=(3.5,3), dpi=150)
for i in range(I2-5,I2+5):
    ax.plot(data2[i,J2:J22,tind2], label=i)
ax.tick_params(
    axis="both", which='both', labelsize=9, direction='in', 
    left=True, bottom=True, right=True, top=True
)
ax.minorticks_on()
ax.set_title(shotn2, fontsize=9)
plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
shotn3 = 51151
twant3 = 0.420021

trange = [twant3-dtime, twant3+dtime]
data3, time3 = HSV.get(shotn3, trange=trange)
tind3 = fn.findNearest(time3, twant3)

# %%
I3 = 243
J3 = 0
J33 = 250

fig, ax= plt.subplots(1, 1, figsize=(3.5,3), dpi=150)
im=ax.imshow(data3[:,:,tind3], vmin=0, vmax=100.,)
fig.colorbar(im, ax=ax)
ax.plot([J3,J33], [I3,I3], '-', c='C3', lw=0.8)
ax.tick_params(
    axis="both", which='both', labelsize=9, direction='in', 
    left=True, bottom=True, right=True, top=True
)
ax.minorticks_on()
ax.set_title(shotn3, fontsize=9)
plt.tight_layout()


fig, ax= plt.subplots(1, 1, figsize=(3.5,3), dpi=150)
for i in range(I3-5,I3+5):
    ax.plot(data3[i,J3:J33,tind3], label=i)
ax.tick_params(
    axis="both", which='both', labelsize=9, direction='in', 
    left=True, bottom=True, right=True, top=True
)
ax.minorticks_on()
ax.set_title(shotn3, fontsize=9)
plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
shotn4 = 51152
twant4 = 0.420026

trange = [twant4-dtime, twant4+dtime]
data4, time4 = HSV.get(shotn4, trange=trange)
tind4 = fn.findNearest(time4, twant4)

# %%
I4 = 243
J4 = 0
J44 = 250

fig, ax= plt.subplots(1, 1, figsize=(3.5,3), dpi=150)
im=ax.imshow(data4[:,:,tind4], vmin=0, vmax=100.,)
fig.colorbar(im, ax=ax)
ax.plot([J4,J44], [I4,I4], '-', c='C3', lw=0.8)
ax.tick_params(
    axis="both", which='both', labelsize=9, direction='in', 
    left=True, bottom=True, right=True, top=True
)
ax.minorticks_on()
ax.set_title(shotn4, fontsize=9)
plt.tight_layout()


fig, ax= plt.subplots(1, 1, figsize=(3.5,3), dpi=150)
for i in range(I4-5,I4+5):
    ax.plot(data4[i,J4:J44,tind4], label=i)
ax.tick_params(
    axis="both", which='both', labelsize=9, direction='in', 
    left=True, bottom=True, right=True, top=True
)
ax.minorticks_on()
ax.set_title(shotn4, fontsize=9)
plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
shotna = 50936
twanta = 0.500013

trange = [twanta-dtime, twanta+dtime]
dataa, timea = HSV.get(shotna, trange=trange)
tinda = fn.findNearest(timea, twanta)

# %%
tinda = 500
Ia = 243
Ja = 0
Jaa = 250

fig, ax= plt.subplots(1, 1, figsize=(3.5,3), dpi=150)
im=ax.imshow(dataa[:,:,tinda], vmin=0, vmax=100.,)
fig.colorbar(im, ax=ax)
ax.plot([Ja,Jaa], [Ia,Ia], '-', c='C4', lw=0.8)
ax.tick_params(
    axis="both", which='both', labelsize=9, direction='in', 
    left=True, bottom=True, right=True, top=True
)
ax.minorticks_on()
ax.set_title(shotna, fontsize=9)
plt.tight_layout()


fig, ax= plt.subplots(1, 1, figsize=(3.5,3), dpi=150)
for i in range(Ia-5,Ia+5):
    ax.plot(dataa[i,Ja:Jaa,tinda], label=i)
ax.tick_params(
    axis="both", which='both', labelsize=9, direction='in', 
    left=True, bottom=True, right=True, top=True
)
ax.minorticks_on()
ax.set_title(shotna, fontsize=9)
plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
shotn5 = 51154
twant5 = 0.632826

trange = [twant5-dtime, twant5+dtime]
data5, time5 = HSV.get(shotn5, trange=trange)
tind5 = fn.findNearest(time5, twant5)

# %%
I5 = 243
J5 = 0
J55 = 250

fig, ax= plt.subplots(1, 1, figsize=(3.5,3), dpi=150)
im=ax.imshow(data5[:,:,tind5], vmin=0, vmax=100.,)
fig.colorbar(im, ax=ax)
ax.plot([J5,J55], [I5,I5], '-', c='C3', lw=0.8)
ax.tick_params(
    axis="both", which='both', labelsize=9, direction='in', 
    left=True, bottom=True, right=True, top=True
)
ax.minorticks_on()
ax.set_title(shotn5, fontsize=9)
plt.tight_layout()


fig, ax= plt.subplots(1, 1, figsize=(3.5,3), dpi=150)
for i in range(I5-5,I5+5):
    ax.plot(data5[i,J5:J55,tind5], label=i)
ax.tick_params(
    axis="both", which='both', labelsize=9, direction='in', 
    left=True, bottom=True, right=True, top=True
)
ax.minorticks_on()
ax.set_title(shotn5, fontsize=9)
plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
shotn6 = 51155
twant6 = 0.486986

trange = [twant6-dtime, twant6+dtime]
data6, time6 = HSV.get(shotn6, trange=trange)
tind6 = fn.findNearest(time6, twant6)

# %%
I6 = 243
J6 = 0
J66 = 250

fig, ax= plt.subplots(1, 1, figsize=(3.5,3), dpi=150)
im=ax.imshow(data6[:,:,tind6], vmin=0, vmax=100.,)
fig.colorbar(im, ax=ax)
ax.plot([J6,J66], [I6,I6], '-', c='C3', lw=0.8)
ax.tick_params(
    axis="both", which='both', labelsize=9, direction='in', 
    left=True, bottom=True, right=True, top=True
)
ax.minorticks_on()
ax.set_title(shotn6, fontsize=9)
plt.tight_layout()


fig, ax= plt.subplots(1, 1, figsize=(3.5,3), dpi=150)
for i in range(I6-5,I6+5):
    ax.plot(data6[i,J6:J66,tind6], label=i)
ax.tick_params(
    axis="both", which='both', labelsize=9, direction='in', 
    left=True, bottom=True, right=True, top=True
)
ax.minorticks_on()
ax.set_title(shotn6, fontsize=9)
plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
shotn7 = 51156
twant7 = 0.459386

trange = [twant7-dtime, twant7+dtime]
data7, time7 = HSV.get(shotn7, trange=trange)
tind7 = fn.findNearest(time7, twant7)

# %%
I7 = 243
J7 = 0
J77 = 250

fig, ax= plt.subplots(1, 1, figsize=(3.5,3), dpi=150)
im=ax.imshow(data7[:,:,tind7], vmin=0, vmax=100.,)
fig.colorbar(im, ax=ax)
ax.plot([J7,J77], [I7,I7], '-', c='C3', lw=0.8)
ax.tick_params(
    axis="both", which='both', labelsize=9, direction='in', 
    left=True, bottom=True, right=True, top=True
)
ax.minorticks_on()
ax.set_title(shotn7, fontsize=9)
plt.tight_layout()


fig, ax= plt.subplots(1, 1, figsize=(3.5,3), dpi=150)
for i in range(I7-5,I7+5):
    ax.plot(data7[i,J7:J77,tind7], label=i)
ax.tick_params(
    axis="both", which='both', labelsize=9, direction='in', 
    left=True, bottom=True, right=True, top=True
)
ax.minorticks_on()
ax.set_title(shotn7, fontsize=9)
plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dI = 5
dt = 5
fig, ax = plt.subplots(1, 2, figsize=(5.5,3), dpi=150, sharex=True, sharey=True)
ax[0].plot(data1[I1-dI:I1+dI,J1:J11,tind1].mean(axis=0), label=f'{shotn1} ref')
ax[0].plot(data0[I0-dI:I0+dI,J0:J00,tind0].mean(axis=0), label=f'{shotn0} 10us')
ax[0].plot(data2[I2-dI:I2+dI,J2:J22,tind2].mean(axis=0), label=f'{shotn2} 15us SXD')
ax[0].plot(data3[I3-dI:I3+dI,J3:J33,tind3].mean(axis=0), label=f'{shotn3} 15us')
ax[0].plot(data4[I4-dI:I4+dI,J4:J44,tind4].mean(axis=0), label=f'{shotn4} 20us SXD')
ax[0].plot(data5[I5-dI:I5+dI,J5:J55,tind5].mean(axis=0), label=f'{shotn5} 20us 600kA SS')
ax[0].plot(data6[I6-dI:I6+dI,J6:J66,tind6].mean(axis=0), label=f'{shotn6} 20us 600kA')
ax[0].plot(data7[I7-dI:I7+dI,J7:J77,tind7].mean(axis=0), label=f'{shotn7} 20us 600kA SS')
ax[0].plot(dataa[Ia-dI:Ia+dI,Ja:Jaa,tinda].mean(axis=0), '--k', lw=0.8, label=f'{shotna} ref 2B')
ax[0].set_xlabel('pixel (#)')
ax[0].set_ylabel('rba (arb)')
ax[0].legend(
    fancybox=1, framealpha=1, fontsize=8, 
    handlelength=0, handletextpad=0, labelcolor='linecolor'
)
ax[0].tick_params(
    axis="both", which='both', labelsize=9, direction='in', 
    left=True, bottom=True, right=True, top=True
)
ax[0].minorticks_on()
ax[0].set_title('average in y', fontsize=9)
xlim = ax[0].get_xlim()
ax[0].set_xlim(xlim)
ax[0].plot(xlim, [0.,0], '-', c='k', lw=0.8, zorder=0)

ax[1].plot(data1[I1,J1:J11,tind1-dt:tind1+dt].mean(axis=-1), label=f'{shotn1} ref')
ax[1].plot(data0[I0,J0:J00,tind0-dt:tind0+dt].mean(axis=-1), label=f'{shotn0} 10us')
ax[1].plot(data2[I2,J2:J22,tind2-dt:tind2+dt].mean(axis=-1), label=f'{shotn2} 15us SXD')
ax[1].plot(data3[I3,J3:J33,tind3-dt:tind3+dt].mean(axis=-1), label=f'{shotn3} 15us')
ax[1].plot(data4[I4,J4:J44,tind4-dt:tind4+dt].mean(axis=-1), label=f'{shotn4} 20us SXD')
ax[1].plot(data5[I5,J5:J55,tind5-dt:tind5+dt].mean(axis=-1), label=f'{shotn5} 20us 600kA SS')
ax[1].plot(data6[I6,J6:J66,tind6-dt:tind6+dt].mean(axis=-1), label=f'{shotn6} 20us 600kA')
ax[1].plot(data7[I7,J7:J77,tind7-dt:tind7+dt].mean(axis=-1), label=f'{shotn7} 20us 600kA SS')
ax[1].plot(dataa[Ia,Ja:Jaa,tinda-dt:tinda+dt].mean(axis=-1), '--k', label=shotna, lw=0.8)
ax[1].set_xlabel('pixel (#)')
ax[1].tick_params(
    axis="both", which='both', labelsize=9, direction='in', 
    left=True, bottom=True, right=True, top=True
)
ax[1].minorticks_on()
ax[1].set_title('average in t', fontsize=9)
xlim = ax[1].get_xlim()
ax[1].set_xlim(xlim)
ax[1].plot(xlim, [0.,0], '-', c='k', lw=0.8, zorder=0)

plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
