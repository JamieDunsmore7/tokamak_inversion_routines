# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.linalg import eigh, solve_banded

# %%
# %matplotlib widget

# %%
xplot = [0.2,1.875]

fig, ax = plt.subplots(1, 1, figsize=(3.5,3), dpi=150)


data = np.load('/home/sthoma/Documents/Results/MU04/Inversions/sys_err_5_scale_1.0x.npz')
R = data['R']
frame = data['frame']
R_grid = data['R_grid']
R_grid_b = (R_grid[1:]+ R_grid[:-1])/2
y = data['y']
y_err = data['y_err']
backprojection = data['backprojection'][0]

ax.plot(R_grid_b, y, '-', c='C0', zorder=2, label='scale=1.0')
ax.fill_between(R_grid_b, y-y_err, y+y_err, color='C0', alpha=0.2, zorder=2)

data = np.load('/home/sthoma/Documents/Results/MU04/Inversions/sys_err_5_scale_1.1x.npz')
R = data['R']
frame = data['frame']
R_grid = data['R_grid']
R_grid_b = (R_grid[1:]+ R_grid[:-1])/2
y = data['y']
y_err = data['y_err']
backprojection = data['backprojection'][0]

ax.plot(R_grid_b, y, '-', c='C1', zorder=2, label='scale=1.1')
ax.fill_between(R_grid_b, y-y_err, y+y_err, color='C1', alpha=0.2, zorder=2)

data = np.load('/home/sthoma/Documents/Results/MU04/Inversions/sys_err_5_scale_1.2x.npz')
R = data['R']
frame = data['frame']
R_grid = data['R_grid']
R_grid_b = (R_grid[1:]+ R_grid[:-1])/2
y = data['y']
y_err = data['y_err']
backprojection = data['backprojection'][0]

ax.plot(R_grid_b, y, '-', c='C2', zorder=2, label='scale=1.2')
ax.fill_between(R_grid_b, y-y_err, y+y_err, color='C2', alpha=0.2, zorder=2)

data = np.load('/home/sthoma/Documents/Results/MU04/Inversions/sys_err_5_scale_1.5x.npz')
R = data['R']
frame = data['frame']
R_grid = data['R_grid']
R_grid_b = (R_grid[1:]+ R_grid[:-1])/2
y = data['y']
y_err = data['y_err']
backprojection = data['backprojection'][0]

ax.plot(R_grid_b, y, '-', c='C3', zorder=2, label='scale=1.5')
ax.fill_between(R_grid_b, y-y_err, y+y_err, color='C3', alpha=0.2, zorder=2)

data = np.load('/home/sthoma/Documents/Results/MU04/Inversions/sys_err_5_scale_1.8x.npz')
R = data['R']
frame = data['frame']
R_grid = data['R_grid']
R_grid_b = (R_grid[1:]+ R_grid[:-1])/2
y = data['y']
y_err = data['y_err']
backprojection = data['backprojection'][0]

ax.plot(R_grid_b, y, '-', c='C4', zorder=2, label='scale=1.75')
ax.fill_between(R_grid_b, y-y_err, y+y_err, color='C4', alpha=0.2, zorder=2)

data = np.load('/home/sthoma/Documents/Results/MU04/Inversions/sys_err_5_scale_2.0x.npz')
R = data['R']
frame = data['frame']
R_grid = data['R_grid']
R_grid_b = (R_grid[1:]+ R_grid[:-1])/2
y = data['y']
y_err = data['y_err']
backprojection = data['backprojection'][0]

ax.plot(R_grid_b, y, '-', c='C5', zorder=2, label='scale=2.0')
ax.fill_between(R_grid_b, y-y_err, y+y_err, color='C5', alpha=0.2, zorder=2)

data = np.load('/home/sthoma/Documents/Results/MU04/Inversions/sys_err_5_scale_2.5x.npz')
R = data['R']
frame = data['frame']
R_grid = data['R_grid']
R_grid_b = (R_grid[1:]+ R_grid[:-1])/2
y = data['y']
y_err = data['y_err']
backprojection = data['backprojection'][0]

ax.plot(R_grid_b, y, '-', c='C6', zorder=2, label='scale=2.5')
ax.fill_between(R_grid_b, y-y_err, y+y_err, color='C6', alpha=0.2, zorder=2)

ax.plot(R, frame, '-', c='k', zorder=1, label='raw RBA')
ax.set_xlim(xplot)
ax.plot(xplot, [0.,0.], '-k', lw=0.8, zorder=1)
ax.set_xlabel('R (m)', fontsize=9)
ax.set_ylabel('Units', fontsize=9)
ax.legend(fancybox=1, framealpha=1, fontsize=8, ncol=2)
ax.tick_params(axis="both", which='both', labelsize=9, direction='in', 
              left=True, bottom=True, right=True, top=False)

plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
